# %%
cd C:\Users\yulya\PycharmProjects\machine_learning_of_patterns
# Out:
# C:\Users\yulya\PycharmProjects\machine_learning_of_patterns

# %%
import time
import numpy as np
import string
import pandas as pd
import matplotlib.pyplot as plt
from random import randint, random
from typing import Callable, Any, Tuple, List, Optional, Dict, Iterator
from tqdm import tqdm

# %%
from regex.parser import RegexParser

# %%
"""
GRAMMAR:
    <regex> ::= <conc-regex> <alt> <regex> | <conc-regex>
    <conc-regex> ::= <simple-regex> | <simple-regex><conc-regex>
    <simple-regex> ::= <lbr><regex><rbr><unary>? | letter <unary>?
    <alt> ::= "|"
    <lbr> ::= "("
    <rbr> ::= ")"
    <unary> ::= "*"
"""


class RegexGenerator:
    seed = 0
    cur_regex_length = 0
    cur_star_num = 0
    cur_nesting = 0
    cur_regex = ""
    count = -1

    def __init__(
            self, regex_length: int,
            star_num: int, star_nesting: int,
            alphabet_size: int, alphabet: Optional[List[str]] = None):
        assert regex_length >= 1, "regex length must be > 0"
        self.regex_length = regex_length
        self.star_nesting = 0 if star_nesting < 0 else star_nesting
        self.star_num = 0 if star_num < 0 else star_num
        if alphabet is None:
            if alphabet_size < 1:
                alphabet_size = 1
            self.alphabet = list(string.ascii_lowercase)[:alphabet_size] + \
                            list(string.ascii_uppercase)[:alphabet_size]
        else:
            self.alphabet = alphabet

    def change_seed(self, step: int = 1):
        self.seed += step
        # random.seed(self.seed)

    def generate_regex(self) -> str:
        # self.change_seed()
        self.cur_nesting = 0
        self.cur_regex = ""
        self.cur_regex_length = self.regex_length
        self.cur_star_num = self.star_num
        self.__generate_regex()
        return self.cur_regex

    # <regex> ::= <n-alt-regex> <alt> <regex> | <conc-regex>
    def __generate_regex(self):
        if self.cur_regex_length < 1:
            return
        if random.randint(0, 1):
            if self.cur_regex_length > 1:
                self.generate_conc_regex()
            if self.cur_regex_length < 1:
                return
            if self.cur_regex_length != 1:
                self.cur_regex += "|"
                self.__generate_regex()
        else:
            self.generate_conc_regex()

    # <conc-regex> ::= <simple-regex> | <simple-regex><conc-regex>
    def generate_conc_regex(self):
        if random.randint(0, 1):
            self.generate_simple_regex()
            if self.cur_regex_length < 1:
                return
            self.generate_conc_regex()
        else:
            self.generate_simple_regex()

    # <simple-regex> ::= <lbr><regex><rbr><unary>? | letter <unary>?
    def generate_simple_regex(self, br_prob: int = 7):
        if random.randint(0, 10) > br_prob:
            self.cur_regex += self.random_char()
            if self.cur_star_num:
                star_chance = self.cur_regex_length // self.cur_star_num
                if star_chance < 2:
                    star_chance = 2
                v = random.randint(0, star_chance - 1)
            else:
                v = 1
            if not v and self.cur_star_num > 0 and self.cur_nesting < self.star_nesting:
                self.cur_regex += "*"
                self.cur_star_num -= 1
            self.cur_regex_length -= 1
        else:
            if self.cur_star_num:
                star_chance = self.cur_regex_length // self.cur_star_num
                if self.cur_regex_length > self.cur_star_num:
                    star_chance += self.cur_star_num // self.star_nesting
                else:
                    star_chance += self.cur_regex_length // self.star_nesting
                if star_chance < 2:
                    star_chance += 2
                v = random.randint(0, star_chance - 1)
            else:
                v = 1
            if not v and self.cur_star_num > 0 and self.cur_nesting < self.star_nesting:
                self.cur_star_num -= 1
                self.cur_nesting += 1
            else:
                v = 1
            self.cur_regex += "("
            self.__generate_regex()
            self.cur_regex += ")"
            if not v:
                self.cur_regex += "*"
                self.cur_nesting -= 1

    def random_char(self):
        return self.alphabet[random.randint(0, len(self.alphabet) - 1)]

# %%
def generate_stateful_regex(
        length_range: List[int],
        star_num: int, 
        star_nesting: int, 
        alphabet_size: int = 26,
        alphabet: Optional[List[str]] = None) -> str:
    gen = RegexGenerator(length_range[1], star_num, star_nesting, alphabet_size, alphabet)
    regex = ""
    while not (length_range[0] <= len(regex) <= length_range[1]):
        regex = gen.generate_regex()
    return regex


def measure_time(func: Callable, *params) -> Tuple: # in seconds
    t1 = time.perf_counter()
    result = func(*params)
    t2 = time.perf_counter()
    return result, t2 - t1


def count_items_in_regex(regex: str, alphabet_size: int = 26) -> Tuple[int]:
    stars = 0
    letters = 0
    alphabet = list(string.ascii_lowercase)[:alphabet_size] + \
               list(string.ascii_uppercase)[:alphabet_size]
    for c in regex:
        if c in alphabet:
            letters += 1
        elif c == '*':
            stars += 1
    return letters, stars


def get_letters(word: str) -> List[str]:
    letters = []
    alphabet = list(string.ascii_lowercase) + \
               list(string.ascii_uppercase)
    for c in word:
        if c in alphabet:
            letters.append(c)
    return letters


def get_chars(word: str) -> List[str]:
    return sorted(list(set(word)))


def generate_word_group(
    step: int = 10, max_n: int = 50, 
    length_range: List[int] = [3, 30],
    alphabet: Optional[List[str]] = None) -> List[str]:
    if alphabet is None:
        alphabet = list(string.ascii_lowercase + string.ascii_uppercase)
    alphabet_len = len(alphabet)
    pattern = []
    mask = []
    length = randint(length_range[0], length_range[1])
    for i in range(length):
        if i < len(alphabet):
            pattern.append(alphabet[i])
        else:
            pattern.append(alphabet[randint(0, alphabet_len - 1)])
        mask.append(randint(0, 1))
    return ("".join(pattern), 
            ["".join([p * n if mask[i] else p for i, p in enumerate(pattern)]) for n in range(0, max_n + 1, step)])


def detect_exp(
        length: List[int], 
        time: List[float], 
        c1_range: Iterator[int], 
        c2_range: Iterator[int]) -> bool:
    for c1 in c1_range:
        for c2 in c2_range:
            exp = False
            for l, t in zip(length, time):
                if t >= 10**c1 * l**4 + 10**c2:
                    exp = True
                else:
                    exp = False
                    break
            if exp:
                return True
    return False


def plot_dependence(df: pd.DataFrame):
    plt.figure(figsize=(10, 5))
    xs = df['length'][::3] 
    types = df['matching_type'].unique()
    for label in types:
        plt.plot(xs, df[df['matching_type'] == label]['time'], label=label)
    plt.ylabel('Time, sec')
    plt.xlabel('Step')
    plt.legend()
    plt.show();

# %%
def test(
        generate_word_group: Callable, 
        step: int = 10, max_n: int = 50,
        plot: bool = False) -> pd.DataFrame:
    regex_str = generate_stateful_regex([15, 50], 20, 40, alphabet=None)
    alphabet = get_letters(regex_str)
    pattern, words = generate_word_group(step, max_n, alphabet=alphabet)
    print(pattern)
    print(regex_str)
    print(words[1])
    regex = RegexParser(regex_str, [max_n ** 2] * regex_str.count('*')).parse()
    nfa = regex.to_nfa()
    dfa = nfa.to_dfa()

    data = {
        "regex": regex,
        "nfa": nfa,
        "dfa": dfa
    }
    results = {
        "length": [],
        "matching_type": [],
        "time": [],
        "match": []
    }
    
    for word in words:
        for k, v in data.items():
            match, t = measure_time(v.match, word)
            results["length"].append(len(word))
            results["matching_type"].append(k)
            results["time"].append(t)
            results["match"].append(match)
            
    df = pd.DataFrame(data=results)
    if plot:
        plot_dependence(df)
    return words, regex_str, df

# %% [markdown]
# ### Testing

# %%
data={"regex": [], "is_target": []}
all_words = []

for i in range(300):
    words, regex, result = test(generate_word_group, 10, 100)
    all_words.append(words)
    data["regex"].append(regex)
    is_exp = False
    for name in ["regex", "nfa", "dfa"]:
        is_exp = detect_exp(
            result[result['matching_type'] == name]["length"], 
            result[result['matching_type'] == name]["time"], 
            range(2, -10, -1), range(2, -10, -1))
        if is_exp:
            break
    data["is_target"].append(is_exp)
    
df = pd.DataFrame(data=data)
# Out:
# IuLzKJuzIuIIJzuLIKuIILJ
# I(u)L*(((z)K*(J)*)*)
# IuLLLLLLLLLLzzzzzzzzzzKJJJJJJJJJJuuuuuuuuuuzIIIIIIIIIIuuuuuuuuuuIIIIIIIIIIIIIIIIIIIIJzuuuuuuuuuuLIIIIIIIIIIKuIIIIIIIIIIILLLLLLLLLLJ
# IHHFxFFIFFFFxFx
# ((I*)*(H*)H)*((F|x*))*|FF*
# IHHHHHHHHHHHHHHHHHHHHFxxxxxxxxxxFFFFFFFFFFFFFFFFFFFFIIIIIIIIIIFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFxFx
# PUhIA
# ((P)(U*))((h)*I|A*)
# PPPPPPPPPPUUUUUUUUUUhhhhhhhhhhIA
# dwkTzTzwkdTwT
# (((d*|(wk*)*T*)*|((z*)*)))
# ddddddddddwkkkkkkkkkkTzzzzzzzzzzTTTTTTTTTTzwwwwwwwwwwkddddddddddTTTTTTTTTTwwwwwwwwwwT
# GrvyNNrGNvGGrGrrGGyvGrN
# Gr*|(v((y*)*)*)*|N
# GrrrrrrrrrrvyNNNNNNNNNNNNNNNNNNNNrGNNNNNNNNNNvvvvvvvvvvGGGGGGGGGGGrGrrrrrrrrrrrGGGGGGGGGGGGGGGGGGGGyvvvvvvvvvvGGGGGGGGGGrN
# eXCwoWrtwCWeoX
# (((eX*(Cw)o*)W*)*|r)*|t*
# eeeeeeeeeeXXXXXXXXXXCwwwwwwwwwwoWWWWWWWWWWrttttttttttwCCCCCCCCCCWWWWWWWWWWeoXXXXXXXXXX
# lmwQQQ
# l*((((m*|w*)|Q*))*)
# lmmmmmmmmmmwQQQ
# bGenT
# b*|(G)(e)*(n*)*T*y
# bbbbbbbbbbGeeeeeeeeeenT
# nKihVhnhiKhiihhKii
# ((n*|((K*(i))|h*)*)V*)*
# nnnnnnnnnnKihVhnhiiiiiiiiiiKKKKKKKKKKhiiiiiiiiiiihhhhhhhhhhhhhhhhhhhhKiiiiiiiiiii
# FrmQMrmMQmQMmrFQrQFFFmmr
# (F*)|((r)*mQ*M)
# FrmQMMMMMMMMMMrrrrrrrrrrmmmmmmmmmmMQmQQQQQQQQQQMMMMMMMMMMmmmmmmmmmmrrrrrrrrrrFQQQQQQQQQQrQQQQQQQQQQFFFmmmmmmmmmmmr
# EypKwll
# ((((E)*)y*p*K|w*))*l
# EyyyyyyyyyyppppppppppKwwwwwwwwwwllllllllllllllllllll
# sDzcwcDzscccccwDwzzccwDcc
# s((D((z*|(c)*)))*w)
# ssssssssssDDDDDDDDDDzzzzzzzzzzcwcDzssssssssssccccccccccccccccccccccccccccccccwDwwwwwwwwwwzzzzzzzzzzzzzzzzzzzzccccccccccccccccccccwDcccccccccccccccccccc
# guRgRRuuugRgRgugRRguuuRRgguRug
# ((g)|((u*)R*))*
# guRgRRRRRRRRRRRRRRRRRRRRuuuuuuuuuuuugRgRRRRRRRRRRguggggggggggRRRRRRRRRRRguuuuuuuuuuuuRRRRRRRRRRRgggggggggggggggggggguRugggggggggg
# FieTUMOiFOFFeUF
# ((Fi((e*))T))|U(M)*O
# FieeeeeeeeeeTTTTTTTTTTUUUUUUUUUUMMMMMMMMMMOiiiiiiiiiiFOFFFFFFFFFFFFFFFFFFFFeeeeeeeeeeUUUUUUUUUUFFFFFFFFFF
# EqELoQcLqEELoQLo
# (E*)*(qE*|L*|o*)Qc*
# EEEEEEEEEEqqqqqqqqqqELLLLLLLLLLooooooooooQQQQQQQQQQccccccccccLqqqqqqqqqqEEEEEEEEEEEEEEEEEEEELLLLLLLLLLooooooooooQQQQQQQQQQLo
# UPAQLtNrHFAAtNHAtN
# U*|P|AQ*(L*)((t|(N*|r*)((H*)*)|F))
# UUUUUUUUUUPPPPPPPPPPAAAAAAAAAAQLLLLLLLLLLtNNNNNNNNNNrHFFFFFFFFFFAAtNNNNNNNNNNHHHHHHHHHHAAAAAAAAAAtN
# BgppAZwBZBApppAApgZAZgBBgwB
# (B*g((p)*|p*A)*Z)*w
# BBBBBBBBBBgpppppppppppAZZZZZZZZZZwBBBBBBBBBBZZZZZZZZZZBBBBBBBBBBAppppppppppppAAAAAAAAAAApgZAAAAAAAAAAZZZZZZZZZZggggggggggBBBBBBBBBBBggggggggggwB
# HhRiOezOzHhiRhiei
# (((H*))|h(R*(i*|O)*|ez)*)*
# HhRiiiiiiiiiiOOOOOOOOOOeeeeeeeeeezzzzzzzzzzOOOOOOOOOOzHhhhhhhhhhhiiiiiiiiiiRhiiiiiiiiiieeeeeeeeeeiiiiiiiiii
# PkuYppcppcuPpkccP
# P(ku*(Y)*)*((p*)p)*c
# PkkkkkkkkkkuYYYYYYYYYYppppppppppppppppppppccccccccccppccccccccccuPPPPPPPPPPpkcccccccccccP
# LUZaUZUUZaUaZaULaU
# ((((L)*))*UZ)|a
# LUZaUZZZZZZZZZZUUUUUUUUUUUZZZZZZZZZZaaaaaaaaaaUUUUUUUUUUaZZZZZZZZZZaULLLLLLLLLLaaaaaaaaaaU
# ZavFxZFFaxvFFFZZZZx
# (Z*|a*)(v)*(F*)*x
# ZZZZZZZZZZavvvvvvvvvvFFFFFFFFFFxxxxxxxxxxZZZZZZZZZZFFFFFFFFFFFFFFFFFFFFaxvvvvvvvvvvFFFFFFFFFFFFZZZZZZZZZZZZZZZZZZZZZZxxxxxxxxxx
# xASgjBgxSjSjxxSjjASgAxAjBAAA
# x|A((S|g)*|(j*)*)B
# xxxxxxxxxxAAAAAAAAAASgjBBBBBBBBBBggggggggggxSjjjjjjjjjjSjjjjjjjjjjxxxxxxxxxxxSjjjjjjjjjjjjjjjjjjjjAAAAAAAAAASgAxAAAAAAAAAAjjjjjjjjjjBBBBBBBBBBAAAAAAAAAAAA
# Zdqeedqdd
# ((Z)*)*|(d*|q)*e*
# ZZZZZZZZZZdqeeeeeeeeeeeddddddddddqddddddddddd
# CSodCCSCCdodoSoSoo
# (C*((((S*))o)*))d
# CSoddddddddddCCCCCCCCCCCSSSSSSSSSSCCCCCCCCCCCdoooooooooodooooooooooSooooooooooSoo
# EQOqUbdqd
# (E)|((Q*((Oq))*|(U*|bd)*)*)*
# EEEEEEEEEEQOqUbdqqqqqqqqqqd
# hVMphhMpppVVhh
# ((h*)|V|M((p*)))
# hVVVVVVVVVVMphhhhhhhhhhhMMMMMMMMMMpppppppppppppppppppppVVhhhhhhhhhhhhhhhhhhhh
# akWoWWkakWkWkaaoWkWWaWkWkaok
# ak((W)*|o*)*|W*|W*
# akkkkkkkkkkWooooooooooWWWWWWWWWWWkakWWWWWWWWWWkWkaaaaaaaaaaaooooooooooWWWWWWWWWWkWWWWWWWWWWWaWkkkkkkkkkkWWWWWWWWWWkaaaaaaaaaaooooooooookkkkkkkkkk
# acEqacEaaEEEaqqEcEqEacaqE
# (a(((c*)E))*q*)*
# aaaaaaaaaacEEEEEEEEEEqacEEEEEEEEEEaaaaaaaaaaaaaaaaaaaaEEEEEEEEEEEEaaaaaaaaaaqqqqqqqqqqqEEEEEEEEEEcEEEEEEEEEEqqqqqqqqqqEEEEEEEEEEaaaaaaaaaaccccccccccaqqqqqqqqqqEEEEEEEEEE
# HAjaxCDkkHDaDDADkjCxjAajx
# H*(A)*j(a|(x*)C)Dk*
# HHHHHHHHHHAjaaaaaaaaaaxxxxxxxxxxCCCCCCCCCCDDDDDDDDDDkkkkkkkkkkkHHHHHHHHHHDaaaaaaaaaaDDDDDDDDDDDDDDDDDDDDADkjjjjjjjjjjCCCCCCCCCCxjjjjjjjjjjAAAAAAAAAAajjjjjjjjjjx
# NxvvxvNxxvvNNvvvxxxvxNxNvxxvv
# (N*)*|((x*(v*))*)*
# NNNNNNNNNNxvvvvvvvvvvvvvvvvvvvvxxxxxxxxxxvNxxxxxxxxxxxxxxxxxxxxvvNNNNNNNNNNNvvvvvvvvvvvvvvvvvvvvvxxxxxxxxxxxxvxNxNNNNNNNNNNvvvvvvvvvvxxxxxxxxxxxvvvvvvvvvvvvvvvvvvvv
# BSlwMffSBffwS
# B*(Slw(M*)*)*f*
# BBBBBBBBBBSlwMfffffffffffSBffwwwwwwwwwwSSSSSSSSSS
# WuTlddWl
# ((Wu*)*T*|(l))|d*
# WuuuuuuuuuuTlllllllllldddddddddddWWWWWWWWWWl
# waywywywy
# ((w)((a*)*)*y*)
# waaaaaaaaaaywyyyyyyyyyywwwwwwwwwwyyyyyyyyyywwwwwwwwwwyyyyyyyyyy
# wjJjwwwwJwjwwjwjwjJwjJJw
# ((((w(j)))|(J)*)*)
# wjJjjjjjjjjjjwwwwwwwwwwwwwwwwwwwwwwJwjwwwwwwwwwwwwwwwwwwwwjjjjjjjjjjwjjjjjjjjjjwwwwwwwwwwjJwwwwwwwwwwjjjjjjjjjjJJwwwwwwwwww
# pSRMXppRMpSpRSXpMXRXSRX
# (p|(S(R((M*X)))*)*)*
# pSRMMMMMMMMMMXXXXXXXXXXppRMMMMMMMMMMppppppppppSppppppppppRSXXXXXXXXXXppppppppppMXXXXXXXXXXRXXXXXXXXXXSRXXXXXXXXXX
# HWZboBo
# ((HWZ(((b*o*)*))*)(B*)*)*
# HHHHHHHHHHWZZZZZZZZZZboBBBBBBBBBBoooooooooo
# gmSXyGDym
# (g*(mS)X*y|G*|D*)
# gmmmmmmmmmmSXyyyyyyyyyyGDDDDDDDDDDym
# ZgfPfggZZgZPf
# ((Z*|g*))*|f*P*
# ZZZZZZZZZZggggggggggffffffffffPffffffffffggggggggggggggggggggZZZZZZZZZZZgZPffffffffff
# WOOOOOWWOOOWWOOOWWW
# (((((W))(O)))*)*
# WOOOOOWWWWWWWWWWWOOOOOOOOOOOOWWWWWWWWWWWWWWWWWWWWOOOOOOOOOOOOOOOOOOOOOWWWWWWWWWWWWWWWWWWWWW
# omAyOmmOommmoyomO
# o*((m*)*|A*y*|O)
# ommmmmmmmmmAAAAAAAAAAyyyyyyyyyyOOOOOOOOOOmmOOOOOOOOOOommmmmmmmmmmmoyoooooooooomO
# dUxxxdU
# (((d)*)|((U*)|x*))*
# ddddddddddUUUUUUUUUUxxxxxxxxxxxxdU
# vgHavgHvgggaaHvg
# (v*)(g*((H)))a*
# vgHavvvvvvvvvvggggggggggHvvvvvvvvvvgggaaaaaaaaaaaaaaaaaaaaHvgggggggggg
# YJyBDDJJyyJBJJJJJBDBJJB
# Y((J)y*|(B*))(D*)*
# YJJJJJJJJJJyyyyyyyyyyBDDDDDDDDDDDJJJJJJJJJJJyyyyyyyyyyyJJJJJJJJJJBBBBBBBBBBJJJJJJJJJJJJJJJJJJJJJJJJJJJJJJJJJJJJJJJJJBBBBBBBBBBDBJJB
# UIHLELULI
# U|((I*)*|(H))*((L*)*)E
# UUUUUUUUUUIHHHHHHHHHHLEEEEEEEEEELULI
# CONIAuQCQQOCQOCIN
# (CO*(N*(I)*)*A)*|u(Q)*
# CCCCCCCCCCOOOOOOOOOONNNNNNNNNNIAuuuuuuuuuuQCQQQQQQQQQQQOCCCCCCCCCCQOOOOOOOOOOCCCCCCCCCCIIIIIIIIIINNNNNNNNNN
# wbdwdddwdbbdwbwwdwwwdddbwdddwb
# ((w*)(b)*)|(d*)
# wwwwwwwwwwbbbbbbbbbbddddddddddwwwwwwwwwwdddddddddddddddddddddwwwwwwwwwwdbbbbbbbbbbbbbbbbbbbbddddddddddwwwwwwwwwwbwwwwwwwwwwwddddddddddwwwwwwwwwwwwwwwwwwwwwdddddddddddddddddddddbwdddddddddddddddddddddwwwwwwwwwwb
# GoukyoG
# ((G|(ou|k))*|y)*
# GouuuuuuuuuukyyyyyyyyyyooooooooooGGGGGGGGGG
# PaAjTAaAaTjPAaATajPTAA
# P*|a*((A*j*|T)*)*
# PaaaaaaaaaaAAAAAAAAAAjTTTTTTTTTTAAAAAAAAAAaaaaaaaaaaAaTTTTTTTTTTjPPPPPPPPPPAAAAAAAAAAaAAAAAAAAAATaaaaaaaaaajPTTTTTTTTTTAAAAAAAAAAAAAAAAAAAA
# oWRWRoWWR
# ((o|(W*)*|((R))))
# ooooooooooWWWWWWWWWWRWWWWWWWWWWRooooooooooWWWWWWWWWWWWWWWWWWWWRRRRRRRRRR
# HeuXM
# H*(((e*)|((u*(XM)|B*B*)*))*)*
# HeuuuuuuuuuuXMMMMMMMMMM
# SIgGg
# (SI*(g|G*g*)*)|L*
# SIIIIIIIIIIggggggggggGGGGGGGGGGgggggggggg
# IcNFMFIN
# ((I)*(c|N*)F)*M
# IIIIIIIIIIcNFMMMMMMMMMMFIIIIIIIIIIN
# uEZEaZuEaaEEZuEaaEEuZEEZuuE
# ((u(E)*))(Z*)|E*|a
# uEEEEEEEEEEZZZZZZZZZZEEEEEEEEEEaaaaaaaaaaZuuuuuuuuuuEaaaaaaaaaaaEEEEEEEEEEEZZZZZZZZZZuEEEEEEEEEEaaaaaaaaaaaaaaaaaaaaEEEEEEEEEEEuuuuuuuuuuZZZZZZZZZZEEZuuuuuuuuuuuuuuuuuuuuE
# fHwlaflla
# f|(H*w)*|(l*a*)
# fHHHHHHHHHHwllllllllllaffffffffffllllllllllllllllllllaaaaaaaaaa
# mmcihzTmTczziTzTmTTmmmiizTi
# m((mc|(i*h*)(z*)T*)*)*
# mmciiiiiiiiiihzzzzzzzzzzTmmmmmmmmmmTczzzzzzzzzzziiiiiiiiiiTTTTTTTTTTzTTTTTTTTTTmTTTTTTTTTTTmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmiiiiiiiiiiizzzzzzzzzzTTTTTTTTTTiiiiiiiiii
# ibZdNwXZXwwNZXiZdXXwwdXb
# (ib(Z*d|N))|w*X*
# iiiiiiiiiibZddddddddddNNNNNNNNNNwwwwwwwwwwXXXXXXXXXXZXXXXXXXXXXwwwwwwwwwwwNZXXXXXXXXXXiiiiiiiiiiZZZZZZZZZZdXXXXXXXXXXXXXXXXXXXXwwddddddddddXXXXXXXXXXb
# RWQfOz
# (((R*|(W|(Q)*f*))*)|O)*(((z))*)
# RRRRRRRRRRWWWWWWWWWWQfOz
# UHaaaUHaUHU
# ((U)|((H|a)*)*)*
# UUUUUUUUUUHHHHHHHHHHaaaaaaaaaaaaUHaUUUUUUUUUUHHHHHHHHHHU
# NRNJNRJNRJJRRRJNRNNNNNJR
# N*|((R*(N*)*))J*
# NNNNNNNNNNRRRRRRRRRRNJNNNNNNNNNNRJNRJJJJJJJJJJJJJJJJJJJJRRRRRRRRRRRRRRRRRRRRRJNRNNNNNJRRRRRRRRRR
# ETARMXTWMXXTTAXWTRATAAEMEXMXX
# ((((E*(T|ARM*)((X))T*|W*)*))*)*
# EEEEEEEEEETTTTTTTTTTAAAAAAAAAARRRRRRRRRRMMMMMMMMMMXXXXXXXXXXTWMXXXXXXXXXXXXXXXXXXXXTTTTTTTTTTTAXXXXXXXXXXWTTTTTTTTTTRATTTTTTTTTTAAAAAAAAAAAEEEEEEEEEEMEEEEEEEEEEXXXXXXXXXXMMMMMMMMMMXX
# bRYKRbRbKYKKYYKRRKbYRYYbKYbb
# (b((R*|Y)))(K*)
# bbbbbbbbbbRYYYYYYYYYYKKKKKKKKKKRRRRRRRRRRbbbbbbbbbbRRRRRRRRRRbbbbbbbbbbKKKKKKKKKKYKKKKKKKKKKKKKKKKKKKKYYYYYYYYYYYKKKKKKKKKKRRRRRRRRRRRKKKKKKKKKKbbbbbbbbbbYYYYYYYYYYRRRRRRRRRRYYYYYYYYYYYbbbbbbbbbbKYbbbbbbbbbbb
# qRnjCykq
# (q(R*n*))*|j*|C*y|((k*))*
# qqqqqqqqqqRnjCCCCCCCCCCyyyyyyyyyykqqqqqqqqqq
# NfTrxTrrxrrfNrTrxNNrrxxTrTrfx
# (((N*)*)*(f|T*)*)r(x)
# NNNNNNNNNNffffffffffTTTTTTTTTTrrrrrrrrrrxTrrrrrrrrrrrrrrrrrrrrxxxxxxxxxxrrrrrrrrrrrfNNNNNNNNNNrTTTTTTTTTTrxxxxxxxxxxNNNNNNNNNNNrrrrrrrrrrrxxxxxxxxxxxTTTTTTTTTTrTTTTTTTTTTrrrrrrrrrrfx
# bpMMMMbppMMbbbMMMpbMpM
# (b*((p|(M*)))*)*
# bppppppppppMMMMbppppppppppppppppppppMMMMMMMMMMMbbbbbbbbbbbbbbbbbbbbbMMMMMMMMMMMMpbMMMMMMMMMMpMMMMMMMMMM
# CCPteiePeCCCtieeiPiP
# C*((C*|P)*)t|e|i
# CCCCCCCCCCCCCCCCCCCCPPPPPPPPPPtttttttttteeeeeeeeeeiePPPPPPPPPPeeeeeeeeeeCCCCCCCCCCCCttttttttttieeeeeeeeeeeiPPPPPPPPPPiiiiiiiiiiPPPPPPPPPP
# VghyU
# (V*)(g*(hy)*UP)*
# VVVVVVVVVVgggggggggghyyyyyyyyyyU
# aalalalalaaaaalal
# (((a*)*((al)*)))*
# aaaaaaaaaaaaaaaaaaaallllllllllalaaaaaaaaaallllllllllalaaaaaaaaaaaaaallllllllllaaaaaaaaaallllllllll
# aHnea
# (a)*(H*|n*|e*)*
# aaaaaaaaaaHHHHHHHHHHnea
# JqiqiqJqiJqi
# J*|(((q(i))*)*q)*
# JJJJJJJJJJqqqqqqqqqqiiiiiiiiiiqiiiiiiiiiiqqqqqqqqqqJJJJJJJJJJqiiiiiiiiiiJqiiiiiiiiii
# LOvNVvVVLLLVLNNvVONONNOvVONL
# (((L*(O*))v)*)N*|((V)*)*
# LLLLLLLLLLOvvvvvvvvvvNNNNNNNNNNVvvvvvvvvvvVVVVVVVVVVVLLLLLLLLLLLLVLLLLLLLLLLNNvvvvvvvvvvVOOOOOOOOOONOOOOOOOOOONNOvvvvvvvvvvVOOOOOOOOOONL
# TpoPfPfTPpT
# T((p*)(((o)*P|(f)))*)
# TpooooooooooPffffffffffPfTTTTTTTTTTPpTTTTTTTTTT
# OwtNNwNt
# O((((w*|t))(N)*|N)|w)
# OwttttttttttNNNNNNNNNNNNNNNNNNNNwwwwwwwwwwNNNNNNNNNNtttttttttt
# tBxLQeUQeBeeBQxxxUx
# (t*B*)x|(L(Q*))|((e)*)|(U)*
# tBxLLLLLLLLLLQQQQQQQQQQeeeeeeeeeeUUUUUUUUUUQeBBBBBBBBBBeeBBBBBBBBBBQQQQQQQQQQxxxUUUUUUUUUUxxxxxxxxxx
# mQpmQQpmpQQ
# ((m*((Q))*)*)(p)*
# mQppppppppppmmmmmmmmmmQQQQQQQQQQQQQQQQQQQQppppppppppmmmmmmmmmmppppppppppQQQQQQQQQQQQQQQQQQQQ
# xjNxjNNjjjjxjxNxxNjj
# (((x)*)*((((j)))*)*)*N
# xjNNNNNNNNNNxxxxxxxxxxjjjjjjjjjjNNNNNNNNNNNNNNNNNNNNjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjxjjjjjjjjjjxNNNNNNNNNNxxxxxxxxxxxNjjjjjjjjjjjjjjjjjjjj
# WIHRQQ
# (((W*)I(H)|R*|Q)*)
# WIIIIIIIIIIHHHHHHHHHHRQQQQQQQQQQQ
# ufbPpfbpppffffPpbbu
# ((u*|f*|bP*)*p)
# ufbbbbbbbbbbPpfbpppffffffffffffffffffffffPpbbbbbbbbbbbuuuuuuuuuu
# ZUaTwaZ
# (((Z*)*))*U*|(a*|Tw)*
# ZUUUUUUUUUUaTTTTTTTTTTwaZZZZZZZZZZ
# fkr
# (((f)*k|(r*)*(P*)*)*|M)*
# fkrrrrrrrrrr
# mWxBtBWBtxWtxxBW
# ((m)|W|x*|(B*t))
# mmmmmmmmmmWWWWWWWWWWxBtBWWWWWWWWWWBBBBBBBBBBttttttttttxxxxxxxxxxWtxxBBBBBBBBBBWWWWWWWWWW
# TCqYteLU
# (TC*|q*(Yt|e))LU*Z*
# TTTTTTTTTTCqYtttttttttteeeeeeeeeeLLLLLLLLLLU
# OPDHGIq
# (O|((P))*)(D(H*G*)*I*)|q
# OPDDDDDDDDDDHGGGGGGGGGGIq
# JuKXgGnRXgK
# J|(((u*)K*)*(X*g*)*G*)|n*(R*X)*
# JuuuuuuuuuuKKKKKKKKKKXXXXXXXXXXgGGGGGGGGGGnRRRRRRRRRRXXXXXXXXXXggggggggggKKKKKKKKKK
# VCkzkVCVzzzkzkVCkkzCVCV
# (((V*)*C)|k*)|z*
# VCkkkkkkkkkkzzzzzzzzzzkkkkkkkkkkVVVVVVVVVVCCCCCCCCCCVVVVVVVVVVzzzzzzzzzzzzzzzzzzzzzkzkkkkkkkkkkVCCCCCCCCCCkkkkkkkkkkkzCCCCCCCCCCVVVVVVVVVVCCCCCCCCCCV
# tqWqtq
# (t*(q)*((W*))*)*
# ttttttttttqqqqqqqqqqWWWWWWWWWWqqqqqqqqqqtq
# GFtYcltlFFllY
# G*(F*|t)*Y(c*l)*
# GGGGGGGGGGFttttttttttYcltllllllllllFFllllllllllllllllllllY
# gmrlmllll
# ((((g*)*|m|r*|l*)*)*)
# ggggggggggmmmmmmmmmmrllllllllllmmmmmmmmmmlllllllllllll
# KPi
# (((KP))*(((i*))*)*|T|(S*))
# KPi
# JxBexBBeeJBJxexe
# (((J*)*|x))*|(B*e)
# JJJJJJJJJJxxxxxxxxxxBBBBBBBBBBexBBBBBBBBBBBBBBBBBBBBeeJBBBBBBBBBBJJJJJJJJJJxxxxxxxxxxeeeeeeeeeexxxxxxxxxxeeeeeeeeee
# RoObYhbRbobbOOo
# R*|(((o*)*)|ObY((h)*))
# RoObYhhhhhhhhhhbRbobbbbbbbbbbbOOOOOOOOOOOoooooooooo
# fguvsUGHwUovoUGGuvuvGvuuwUHGvH
# (f*(((g*)*)*u|vs*|(U)))(G|Hw*|Uo)*
# ffffffffffguvvvvvvvvvvssssssssssUGHHHHHHHHHHwwwwwwwwwwUUUUUUUUUUovooooooooooUUUUUUUUUUGGuvvvvvvvvvvuvGvvvvvvvvvvuuuuuuuuuuuuuuuuuuuuwUUUUUUUUUUHHHHHHHHHHGGGGGGGGGGvvvvvvvvvvHHHHHHHHHH
# oegj
# ((o(e*|g)*)*|j*c)*
# oeeeeeeeeeeggggggggggjjjjjjjjjj
# rznK
# ((r*)(z*|n*))*KX*
# rrrrrrrrrrznnnnnnnnnnK
# NxSWWxNxx
# ((N*)*((x*)*)|S)W*
# NNNNNNNNNNxxxxxxxxxxSSSSSSSSSSWWxxxxxxxxxxNNNNNNNNNNxxxxxxxxxxx
# cRfDucuDuRRRRccRuu
# (c)|((R*)*)|(f|D*)u*
# ccccccccccRfDDDDDDDDDDuuuuuuuuuucuDDDDDDDDDDuuuuuuuuuuRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRcccccccccccRuuuuuuuuuuuuuuuuuuuu
# tfmiKUUKmfmimKmfKUtmfiff
# ((t)((f*|(((m*|(i*)*))|KU)*)))
# ttttttttttffffffffffmiiiiiiiiiiKKKKKKKKKKUUUUUUUUUUUKmmmmmmmmmmfmimmmmmmmmmmKKKKKKKKKKmffffffffffKKKKKKKKKKUtmffffffffffiiiiiiiiiifffffffffff
# qqGNqNGNNGNqGqqqGqqNG
# (q*|((q*|G*)|N))*
# qqqqqqqqqqqGNNNNNNNNNNqNGGGGGGGGGGNNNNNNNNNNNGNNNNNNNNNNqGqqqqqqqqqqqqGqqqqqqqqqqqNNNNNNNNNNGGGGGGGGGG
# FhhErTdrEhTFdTddEhErrhEh
# F|h|hE|r|(((T*)*)*)d
# FFFFFFFFFFhhhhhhhhhhhEEEEEEEEEErTddddddddddrrrrrrrrrrEhTTTTTTTTTTFdTdddddddddddEEEEEEEEEEhhhhhhhhhhEEEEEEEEEErrrrrrrrrrrhEEEEEEEEEEh
# cfn
# ((c*f*n)|r*)m*|O*
# cfnnnnnnnnnn
# aXFFFXaaFFXFXFaXXXFFXaaaXXaX
# ((a*X*))(((F))*)*
# aXFFFFFFFFFFFFFFFFFFFFFXaaaaaaaaaaaaaaaaaaaaFFFFFFFFFFFXFFFFFFFFFFXFFFFFFFFFFaXXXXXXXXXXXXFFFFFFFFFFFXaaaaaaaaaaaaaaaaaaaaaXXXXXXXXXXXaXXXXXXXXXX
# dmKKK
# (((d))*)((m|K*)*)
# ddddddddddmKKKKKKKKKKKK
# rylyrlyrll
# (((r*)|(y|l)*))*
# rrrrrrrrrryyyyyyyyyyllllllllllyyyyyyyyyyrlyyyyyyyyyyrlllllllllll
# KOKKOOKKKOOOKOOKKKKOKKK
# (((((((K*)*)))*)*)*O)
# KKKKKKKKKKOKKOOOOOOOOOOOKKKKKKKKKKKKKKKKKKKKKOOOOOOOOOOOOOOOOOOOOOKOOKKKKOOOOOOOOOOKKK
# UnidkkkknUkknnknn
# U((n)*)((i*dk))
# UUUUUUUUUUnidkkkkkkkkkkkkkkkkkkkkkknnnnnnnnnnUkkkkkkkkkkknnknn
# cKrrcKrKcKrKrKrKKKKKrKK
# (c*(((K(r*)))))
# cKKKKKKKKKKrrrrrrrrrrrccccccccccKrrrrrrrrrrKcKrKKKKKKKKKKrrrrrrrrrrKKKKKKKKKKrrrrrrrrrrKKKKKKKKKKKKKKrKKKKKKKKKKK
# hsjEEsEsjEEshjjhshjEEhjhh
# (h)*((((s)|j*)*)*)*E*
# hhhhhhhhhhsjjjjjjjjjjEEEEEEEEEEEEEEEEEEEEssssssssssEssssssssssjjjjjjjjjjEEEEEEEEEEEEEEEEEEEEsssssssssshhhhhhhhhhjjjjjjjjjjjhshjjjjjjjjjjEEEEEEEEEEEhhhhhhhhhhjjjjjjjjjjhh
# OedB
# O|e*((dB(g*(v)*))*v*)
# OOOOOOOOOOeeeeeeeeeeddddddddddB
# PCEcHCPCcCcECHPEHCEccEHPCC
# ((P*(C((Ec|H)*C(P*)))*)*C)*
# PCCCCCCCCCCEcHCPCccccccccccCCCCCCCCCCccccccccccECHHHHHHHHHHPPPPPPPPPPEEEEEEEEEEHHHHHHHHHHCEEEEEEEEEEccEEEEEEEEEEHPPPPPPPPPPCC
# xMxzzz
# (x*)M*((((x*))*|z)*)
# xxxxxxxxxxMMMMMMMMMMxzzz
# jxUd
# (j*|((x*U*|d*j*)(m)))
# jxxxxxxxxxxUUUUUUUUUUd
# hmLksCzoLfLLLfmzohCkz
# ((h*m(L*)k|(s*)*)|C)*|(((z*)*))*|oL(f)
# hhhhhhhhhhmLkkkkkkkkkksCzzzzzzzzzzooooooooooLffffffffffLLLLLLLLLLLLLLLLLLLLLfmmmmmmmmmmzohhhhhhhhhhCkkkkkkkkkkzzzzzzzzzz
# KviPxxi
# (((K)))(v*iP*)x*
# KKKKKKKKKKvvvvvvvvvviPxxi
# TwwBttBtwTTttBwwtTBBw
# ((Tw*|(w)*)(B)((t*))*|t)*
# TwwwwwwwwwwwwwwwwwwwwBtttttttttttBBBBBBBBBBttttttttttwTTTTTTTTTTTTTTTTTTTTttBBBBBBBBBBwwwwwwwwwwwttttttttttTTTTTTTTTTBBBBBBBBBBBBBBBBBBBBw
# nzCNGzC
# n*(z|CN*)*|(G)*
# nzzzzzzzzzzCCCCCCCCCCNNNNNNNNNNGGGGGGGGGGzzzzzzzzzzCCCCCCCCCC
# EwrcrwcrEcwrEwErcrcEwcEcr
# (E*|w)*|((r|c*)*)
# EwrrrrrrrrrrcrrrrrrrrrrwwwwwwwwwwccccccccccrrrrrrrrrrEEEEEEEEEEcwrrrrrrrrrrEwErrrrrrrrrrcrrrrrrrrrrccccccccccEEEEEEEEEEwcEEEEEEEEEEcrrrrrrrrrr
# sAzw
# s*|(((A*)(z)*wr*)*)
# sAAAAAAAAAAzzzzzzzzzzw
# Qoy
# ((Q*)*(oy)(O*|H*)*B*)
# Qoyyyyyyyyyy
# icKFjnccKK
# i*|c(((K*)*F)|(j)*)*(n)*
# iiiiiiiiiiccccccccccKKKKKKKKKKFFFFFFFFFFjnnnnnnnnnnccKK
# IzczczcIIcIcIIcIIczzcI
# (I((((z*)|c*))*)*)
# IzzzzzzzzzzcccccccccczcccccccccczzzzzzzzzzccccccccccIIIIIIIIIIIIIIIIIIIIcIcIIcIIIIIIIIIIIcccccccccczzzzzzzzzzzzzzzzzzzzcI
# DaeeDDaeDDaDaDaaa
# D|(((a)*)*|(e))
# DDDDDDDDDDaeeeeeeeeeeeeeeeeeeeeDDaaaaaaaaaaeeeeeeeeeeDDDDDDDDDDDaaaaaaaaaaDaDaaaaaaaaaaaaaaaaaaaaa
# bencaabaeaaeaaecnebecaeenceba
# ((b|e)*|n)c*((a*)*)*
# bbbbbbbbbbencaaaaaaaaaaabaaaaaaaaaaeeeeeeeeeeaaaaaaaaaaaeeeeeeeeeeaaaaaaaaaaaeccccccccccnnnnnnnnnneeeeeeeeeebbbbbbbbbbeccccccccccaaaaaaaaaaeeeeeeeeeeeeeeeeeeeencccccccccceeeeeeeeeebbbbbbbbbbaaaaaaaaaa
# qEEEqEqEEqEqqqqE
# (((q)*)*((E)*))*
# qEEEqEqqqqqqqqqqEEEEEEEEEEEEEEEEEEEEqqqqqqqqqqEqqqqqqqqqqqqqqqqqqqqqqE
# gImt
# ((g*|Im)*|(t*V|(L*))*)*
# ggggggggggIIIIIIIIIImt
# YMkkkkYYYkYkkYkk
# (YM)((((k*)k)*)*)
# YMMMMMMMMMMkkkkkkkkkkkkkYYYYYYYYYYYYYYYYYYYYYkkkkkkkkkkYYYYYYYYYYkkYkkkkkkkkkkk
# DQRgEQEDQDgRRDgE
# D|(Q*)(R*(g*))E*
# DQQQQQQQQQQRgEEEEEEEEEEQEEEEEEEEEEDQDDDDDDDDDDgRRRRRRRRRRRRRRRRRRRRDgE
# yAIrAAIIAIyArA
# (yA((Ir)))*((A*)*)
# yyyyyyyyyyAAAAAAAAAAIrAAAAAAAAAAAIIAAAAAAAAAAIIIIIIIIIIyyyyyyyyyyArAAAAAAAAAA
# pkHaJigvlagpgiivHvivHHJa
# p|k|Ha*|(J((i|g*)v))(l)*
# ppppppppppkHHHHHHHHHHaJigvllllllllllaggggggggggpggggggggggiiiiiiiiiiiiiiiiiiiivvvvvvvvvvHvvvvvvvvvvivvvvvvvvvvHHHHHHHHHHHJJJJJJJJJJa
# ahJtthahJJaaJJhttJhJh
# ((a*)((h)*)J*)t
# ahJttttttttttthhhhhhhhhhaaaaaaaaaahhhhhhhhhhJJaaaaaaaaaaaaaaaaaaaaJJJJJJJJJJJhhhhhhhhhhtttttttttttJhhhhhhhhhhJJJJJJJJJJh
# Notbnbootoob
# (No*((t*b*)))*n
# Nooooooooootbnboottttttttttoobbbbbbbbbb
# CAiiCiAiCAiAiACCCCAi
# ((C)*)(A)((i*))
# CAiiCiAiiiiiiiiiiCCCCCCCCCCAAAAAAAAAAiAAAAAAAAAAiiiiiiiiiiAAAAAAAAAACCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCAAAAAAAAAAi
# seeesessseeesesseeeesesese
# ((((s*)*(e)*)*))*
# seeeeeeeeeeeeeeeeeeeeeseeeeeeeeeessssssssssssssssssssseeeeeeeeeeeeeeeeeeeeesssssssssseeeeeeeeeesssssssssssssssssssseeeesssssssssseseeeeeeeeeeseeeeeeeeee
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_18188\776731590.py in <module>
#       3
#       4 for i in range(300):
# ----> 5     words, regex, result = test(generate_word_group, 10, 100)
#       6     all_words.append(words)
#       7     data["regex"].append(regex)
#
# ~\AppData\Local\Temp\ipykernel_18188\2995196746.py in test(generate_word_group, step, max_n, plot)
#      27     for word in words:
#      28         for k, v in data.items():
# ---> 29             match, t = measure_time(v.match, word)
#      30             results["length"].append(len(word))
#      31             results["matching_type"].append(k)
#
# ~\AppData\Local\Temp\ipykernel_18188\1932446519.py in measure_time(func, *params)
#      14 def measure_time(func: Callable, *params) -> Tuple: # in seconds
#      15     t1 = time.perf_counter()
# ---> 16     result = func(*params)
#      17     t2 = time.perf_counter()
#      18     return result, t2 - t1
#
# ~\PycharmProjects\machine_learning_of_patterns\regex\abstract_regex.py in match(self, word)
#      14     def match(self, word: str) -> bool:
#      15         word_len = len(word)
# ---> 16         for final in self.starts_with(word):
#      17             if final == word_len:
#      18                 return True
#
# ~\PycharmProjects\machine_learning_of_patterns\regex\regex.py in starts_with(self, text)
#     147             used.add(i)
#     148             if h > 0:
# --> 149                 for j in self.value.starts_with(text[i:]):
#     150                     j += i
#     151                     if j not in used:
#
# ~\PycharmProjects\machine_learning_of_patterns\regex\regex.py in starts_with(self, text)
#      58         while stack:
#      59             regex_i, word, k = stack.pop()
# ---> 60             for i in self.value[regex_i].starts_with(word):
#      61                 if regex_i + 1 == len(self.value):
#      62                     yield k + i
#
# ~\PycharmProjects\machine_learning_of_patterns\regex\regex.py in starts_with(self, text)
#     147             used.add(i)
#     148             if h > 0:
# --> 149                 for j in self.value.starts_with(text[i:]):
#     150                     j += i
#     151                     if j not in used:
#
# ~\PycharmProjects\machine_learning_of_patterns\regex\regex.py in starts_with(self, text)
#      58         while stack:
#      59             regex_i, word, k = stack.pop()
# ---> 60             for i in self.value[regex_i].starts_with(word):
#      61                 if regex_i + 1 == len(self.value):
#      62                     yield k + i
#
# ~\PycharmProjects\machine_learning_of_patterns\regex\regex.py in starts_with(self, text)
#     147             used.add(i)
#     148             if h > 0:
# --> 149                 for j in self.value.starts_with(text[i:]):
#     150                     j += i
#     151                     if j not in used:
#
# ~\PycharmProjects\machine_learning_of_patterns\regex\regex.py in starts_with(self, text)
#      59             regex_i, word, k = stack.pop()
#      60             for i in self.value[regex_i].starts_with(word):
# ---> 61                 if regex_i + 1 == len(self.value):
#      62                     yield k + i
#      63                 else:
#
# KeyboardInterrupt:

# %%
df = pd.DataFrame(data=data)

# %%
df
# Out:
#                           regex  is_target
# 0          I(u)L*(((z)K*(J)*)*)      False
# 1    ((I*)*(H*)H)*((F|x*))*|FF*      False
# 2           ((P)(U*))((h)*I|A*)      False
# 3    (((d*|(wk*)*T*)*|((z*)*)))      False
# 4            Gr*|(v((y*)*)*)*|N      False
# ..                          ...        ...
# 125          (yA((Ir)))*((A*)*)      False
# 126    p|k|Ha*|(J((i|g*)v))(l)*      False
# 127             ((a*)((h)*)J*)t      False
# 128             (No*((t*b*)))*n      False
# 129             ((C)*)(A)((i*))      False
#
# [130 rows x 2 columns]

# %%
df[df["is_target"] == True]
# Out:
#                          regex  is_target
# 78    (((f)*k|(r*)*(P*)*)*|M)*       True
# 87  (((KP))*(((i*))*)*|T|(S*))       True

# %%
dataset.to_csv("experiments/dataset.csv", index=False)

# %%
dataset = pd.concat([dataset, df[df["is_target"] == True]], ignore_index=True)

# %%
dataset.to_csv("dataset.csv", index=False)

# %%
dataset
# Out:
#                          regex  is_target
# 0                       l*l*l*       True
# 1                        Z(J)*       True
# 2                       k*|(s)       True
# 3          Q*(((Q)|(Q*)*Q)*Q*)       True
# 4                        (C*)*       True
# ..                         ...        ...
# 76                 (J)((d*)*)*       True
# 77                x*h((Q*|P))*       True
# 78                  (Y*|(m*))*       True
# 79    (((f)*k|(r*)*(P*)*)*|M)*       True
# 80  (((KP))*(((i*))*)*|T|(S*))       True
#
# [81 rows x 2 columns]
